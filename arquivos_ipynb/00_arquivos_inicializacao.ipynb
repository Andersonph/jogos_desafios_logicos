# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# C:\ProgramData\anaconda3\python.exe
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
# !where python
# Out:
# C:\ProgramData\anaconda3\python.exe
# C:\Users\lab-21-p05\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
import sys
# !{sys.executable} -m pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pygame in c:\users\lab-21-p05\appdata\roaming\python\python312\site-packages (2.6.1)

# %%
# !pip --version
# Out:
# pip 24.2 from C:\ProgramData\anaconda3\Lib\site-packages\pip (python 3.12)

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# C:\Users\lab-21-p05\Downloads
# C:\ProgramData\anaconda3\python312.zip
# C:\ProgramData\anaconda3\DLLs
# C:\ProgramData\anaconda3\Lib
# C:\ProgramData\anaconda3
#
# C:\Users\lab-21-p05\AppData\Roaming\Python\Python312\site-packages
# C:\ProgramData\anaconda3\Lib\site-packages
# C:\ProgramData\anaconda3\Lib\site-packages\win32
# C:\ProgramData\anaconda3\Lib\site-packages\win32\lib
# C:\ProgramData\anaconda3\Lib\site-packages\Pythonwin
# C:\ProgramData\anaconda3\Lib\site-packages\setuptools\_vendor

# %%
import site

print(site.getusersitepackages())
# Out:
# C:\Users\lab-21-p05\AppData\Roaming\Python\Python312\site-packages

# %%
# !conda install pygame -y
# Out:
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pygame
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main
#   - https://repo.anaconda.com/pkgs/r
#   - https://repo.anaconda.com/pkgs/msys2
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import pygame
import sys
